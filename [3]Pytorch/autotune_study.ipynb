# %%
from functools import partial
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %% [markdown]
# ### Data loaders
# We wrap the data loaders in their own function and pass a global data directory. This way we can share a data directory between different trials.

# %%
def load_data(data_dir="./data"):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # 3 channels, mean and standard deviation
    ])

    trainset = torchvision.datasets.CIFAR10(
        root=data_dir, train=True, download=True, transform=transform)

    testset = torchvision.datasets.CIFAR10(
        root=data_dir, train=False, download=True, transform=transform)

    return trainset, testset

# %% [markdown]
# ### Configurable neural network

# %%
class Net(nn.Module):
    def __init__(self, l1=120, l2=84):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, l1)
        self.fc2 = nn.Linear(l1, l2)
        self.fc3 = nn.Linear(l2, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ### Full training function

# %%
def train_cifar(config, checkpoint_dir=None, data_dir=None):
    net = Net(config["l1"], config["l2"])

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=config["lr"], momentum=0.9)

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    trainset, testset = load_data(data_dir)

    test_abs = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(
        trainset, [test_abs, len(trainset) - test_abs])

    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)

    for epoch in range(10):  # loop over the dataset multiple times
        running_loss = 0.0
        epoch_steps = 0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if i % 2000 == 1999:  # print every 2000 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,
                                                running_loss / epoch_steps))
                running_loss = 0.0

        # Validation loss
        val_loss = 0.0
        val_steps = 0
        total = 0
        correct = 0
        for i, data in enumerate(valloader, 0):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps), accuracy=correct / total)
    print("Finished Training")

# %% [markdown]
# ### Test set accuracy

# %%
def test_accuracy(net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=4, shuffle=False, num_workers=2)

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):
    data_dir = os.path.abspath("./data")
    load_data(data_dir)
    config = {
        "l1": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "l2": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "lr": tune.loguniform(1e-4, 1e-1),
        "batch_size": tune.choice([2, 4, 8, 16])
    }
    scheduler = ASHAScheduler(
        metric="loss",
        mode="min",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "accuracy", "training_iteration"])
    result = tune.run(
        partial(train_cifar, data_dir=data_dir),
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter=reporter)

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = Net(best_trial.config["l1"], best_trial.config["l2"])
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_acc = test_accuracy(best_trained_model, device)
    print("Best trial test set accuracy: {}".format(test_acc))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=10, max_num_epochs=10, gpus_per_trial=0)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to c:\Users\HYPC300\OneDrive - 한양대학교\GitHub\Deeplearning-Autoencoder-DOA\[3]Pytorch\data\cifar-10-python.tar.gz
# 170499072it [00:41, 4098629.50it/s]
# Extracting c:\Users\HYPC300\OneDrive - 한양대학교\GitHub\Deeplearning-Autoencoder-DOA\[3]Pytorch\data\cifar-10-python.tar.gz to c:\Users\HYPC300\OneDrive - 한양대학교\GitHub\Deeplearning-Autoencoder-DOA\[3]Pytorch\data
# Files already downloaded and verified
# 2022-02-18 20:37:18,276	WARNING experiment.py:255 -- No name detected on trainable. Using DEFAULT.
# 2022-02-18 20:37:18,278	INFO registry.py:69 -- Detected unknown callable for trainable. Converting to class.
# 2022-02-18 20:37:18,658	ERROR syncer.py:111 -- Log sync requires rsync to be installed.
# == Status ==
# Current time: 2022-02-18 20:37:18 (running for 00:00:00.28)
# Memory usage on this node: 20.6/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | PENDING  |                 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | PENDING  |                 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | PENDING  |                 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | PENDING  |                 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | PENDING  |                 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=44984) Files already downloaded and verified
#  pid=44984) Files already downloaded and verified
# == Status ==
# Current time: 2022-02-18 20:37:23 (running for 00:00:05.31)
# Memory usage on this node: 20.9/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=36076) Files already downloaded and verified
#  pid=38900) Files already downloaded and verified
#  pid=45108) Files already downloaded and verified
#  pid=44324) Files already downloaded and verified
#  pid=64192) Files already downloaded and verified
#  pid=36076) Files already downloaded and verified
#  pid=45108) Files already downloaded and verified
#  pid=64192) Files already downloaded and verified
# == Status ==
# Current time: 2022-02-18 20:37:29 (running for 00:00:11.23)
# Memory usage on this node: 22.3/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=38900) Files already downloaded and verified
#  pid=44324) Files already downloaded and verified
# == Status ==
# Current time: 2022-02-18 20:37:34 (running for 00:00:16.29)
# Memory usage on this node: 24.6/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:37:39 (running for 00:00:21.36)
# Memory usage on this node: 26.1/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:37:44 (running for 00:00:26.49)
# Memory usage on this node: 27.6/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:37:49 (running for 00:00:31.58)
# Memory usage on this node: 28.5/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:37:55 (running for 00:00:36.62)
# Memory usage on this node: 28.4/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:38:00 (running for 00:00:41.70)
# Memory usage on this node: 28.1/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:38:05 (running for 00:00:46.79)
# Memory usage on this node: 28.5/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:38:10 (running for 00:00:51.89)
# Memory usage on this node: 29.3/31.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:38:15 (running for 00:00:56.97)
# Memory usage on this node: 31.0/31.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=44984) [1,  2000] loss: 2.271
# == Status ==
# Current time: 2022-02-18 20:38:20 (running for 00:01:02.53)
# Memory usage on this node: 30.3/31.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=44984) [1,  4000] loss: 1.029
#  pid=45108) [1,  2000] loss: 2.032
#  pid=36076) [1,  2000] loss: 2.321
# == Status ==
# Current time: 2022-02-18 20:38:26 (running for 00:01:07.63)
# Memory usage on this node: 30.3/31.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=44324) [1,  2000] loss: 2.156
#  pid=64192) [1,  2000] loss: 2.320
# == Status ==
# Current time: 2022-02-18 20:38:31 (running for 00:01:12.72)
# Memory usage on this node: 30.4/31.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=38900) [1,  2000] loss: 2.241
#  pid=44984) [1,  6000] loss: 0.667
#  pid=45108) [1,  4000] loss: 0.862
# == Status ==
# Current time: 2022-02-18 20:38:36 (running for 00:01:17.84)
# Memory usage on this node: 30.4/31.8 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=36076) [1,  4000] loss: 1.155
#  pid=44324) [1,  4000] loss: 0.882
#  pid=64192) [1,  4000] loss: 1.155
#  pid=44984) [1,  8000] loss: 0.491
# == Status ==
# Current time: 2022-02-18 20:38:41 (running for 00:01:22.93)
# Memory usage on this node: 28.6/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=45108) [1,  6000] loss: 0.546
# == Status ==
# Current time: 2022-02-18 20:38:46 (running for 00:01:28.00)
# Memory usage on this node: 24.8/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=36076) [1,  6000] loss: 0.770
#  pid=44984) [1, 10000] loss: 0.389
# == Status ==
# Current time: 2022-02-18 20:38:51 (running for 00:01:33.07)
# Memory usage on this node: 25.3/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=45108) [1,  8000] loss: 0.401
#  pid=44984) [1, 12000] loss: 0.325
#  pid=36076) [1,  8000] loss: 0.577
# == Status ==
# Current time: 2022-02-18 20:38:56 (running for 00:01:38.14)
# Memory usage on this node: 26.0/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=45108) [1, 10000] loss: 0.316
# == Status ==
# Current time: 2022-02-18 20:39:01 (running for 00:01:43.25)
# Memory usage on this node: 25.5/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=44984) [1, 14000] loss: 0.288
#  pid=36076) [1, 10000] loss: 0.462
# == Status ==
# Current time: 2022-02-18 20:39:06 (running for 00:01:48.34)
# Memory usage on this node: 23.2/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=44984) [1, 16000] loss: 0.242
# == Status ==
# Current time: 2022-02-18 20:39:11 (running for 00:01:53.47)
# Memory usage on this node: 24.5/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
# == Status ==
# Current time: 2022-02-18 20:39:16 (running for 00:01:58.53)
# Memory usage on this node: 25.9/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# | DEFAULT_20a51_00007 | PENDING  |                 |           16 |   64 |   16 | 0.0001704   |
# | DEFAULT_20a51_00008 | PENDING  |                 |            2 |    8 |    4 | 0.0398717   |
# | DEFAULT_20a51_00009 | PENDING  |                 |            4 |   64 |  256 | 0.0458157   |
# +---------------------+----------+-----------------+--------------+------+------+-------------+
#
#
#  pid=44984) [1, 18000] loss: 0.214
# == Status ==
# Current time: 2022-02-18 20:39:22 (running for 00:02:03.61)
# Memory usage on this node: 27.0/31.8 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 12.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (4 PENDING, 6 RUNNING)
# +---------------------+----------+-----------------+--------------+------+------+-------------+
# | Trial name          | status   | loc             |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-----------------+--------------+------+------+-------------|
# | DEFAULT_20a51_00000 | RUNNING  | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  |
# | DEFAULT_20a51_00001 | RUNNING  | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   |
# | DEFAULT_20a51_00002 | RUNNING  | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 |
# | DEFAULT_20a51_00003 | RUNNING  | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 |
# | DEFAULT_20a51_00004 | RUNNING  | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  |
# | DEFAULT_20a51_00005 | RUNNING  | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  |
# | DEFAULT_20a51_00006 | PENDING  |                 |            4 |   16 |   16 | 0.00260165  |
# ...
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_20a51_00003 | RUNNING    | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 | 1.4757  |     0.4649 |                    3 |
# | DEFAULT_20a51_00004 | RUNNING    | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  | 1.38335 |     0.5001 |                    3 |
# | DEFAULT_20a51_00006 | RUNNING    | 127.0.0.1:46640 |            4 |   16 |   16 | 0.00260165  | 1.60342 |     0.43   |                    1 |
# | DEFAULT_20a51_00008 | RUNNING    | 127.0.0.1:38436 |            2 |    8 |    4 | 0.0398717   |         |            |                      |
# | DEFAULT_20a51_00009 | RUNNING    | 127.0.0.1:58256 |            4 |   64 |  256 | 0.0458157   |         |            |                      |
# | DEFAULT_20a51_00000 | TERMINATED | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  | 1.8427  |     0.2846 |                    2 |
# | DEFAULT_20a51_00001 | TERMINATED | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   | 2.31107 |     0.0972 |                    1 |
# | DEFAULT_20a51_00002 | TERMINATED | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 | 2.30503 |     0.097  |                    1 |
# | DEFAULT_20a51_00005 | TERMINATED | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  | 1.55219 |     0.4545 |                    2 |
# | DEFAULT_20a51_00007 | TERMINATED | 127.0.0.1:40848 |           16 |   64 |   16 | 0.0001704   | 2.30338 |     0.1433 |                    1 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
#  pid=38436) [1, 20000] loss: 0.234
# == Status ==
# Current time: 2022-02-18 20:44:36 (running for 00:07:18.39)
# Memory usage on this node: 27.4/31.8 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.5788338211417199 | Iter 1.000: -1.8936227770268916
# Resources requested: 10.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (5 RUNNING, 5 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_20a51_00003 | RUNNING    | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 | 1.4757  |     0.4649 |                    3 |
# | DEFAULT_20a51_00004 | RUNNING    | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  | 1.38335 |     0.5001 |                    3 |
# | DEFAULT_20a51_00006 | RUNNING    | 127.0.0.1:46640 |            4 |   16 |   16 | 0.00260165  | 1.60342 |     0.43   |                    1 |
# | DEFAULT_20a51_00008 | RUNNING    | 127.0.0.1:38436 |            2 |    8 |    4 | 0.0398717   |         |            |                      |
# | DEFAULT_20a51_00009 | RUNNING    | 127.0.0.1:58256 |            4 |   64 |  256 | 0.0458157   |         |            |                      |
# | DEFAULT_20a51_00000 | TERMINATED | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  | 1.8427  |     0.2846 |                    2 |
# | DEFAULT_20a51_00001 | TERMINATED | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   | 2.31107 |     0.0972 |                    1 |
# | DEFAULT_20a51_00002 | TERMINATED | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 | 2.30503 |     0.097  |                    1 |
# | DEFAULT_20a51_00005 | TERMINATED | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  | 1.55219 |     0.4545 |                    2 |
# | DEFAULT_20a51_00007 | TERMINATED | 127.0.0.1:40848 |           16 |   64 |   16 | 0.0001704   | 2.30338 |     0.1433 |                    1 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
#  pid=58256) [1, 10000] loss: 0.466
# Result for DEFAULT_20a51_00006:
#   accuracy: 0.4471
#   date: 2022-02-18_20-44-39
#   done: false
#   experiment_id: 223254349baf450db44d022cfa319be7
#   hostname: DESKTOP-7IDKFF3
#   iterations_since_restore: 2
#   loss: 1.5001266940414906
#   node_ip: 127.0.0.1
#   pid: 46640
#   should_checkpoint: true
#   time_since_restore: 290.9400906562805
#   time_this_iter_s: 138.43585300445557
#   time_total_s: 290.9400906562805
#   timestamp: 1645184679
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 20a51_00006
#
# == Status ==
# Current time: 2022-02-18 20:44:42 (running for 00:07:24.38)
# Memory usage on this node: 22.7/31.8 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.552187786269188 | Iter 1.000: -1.8936227770268916
# Resources requested: 10.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (5 RUNNING, 5 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_20a51_00003 | RUNNING    | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 | 1.4757  |     0.4649 |                    3 |
# | DEFAULT_20a51_00004 | RUNNING    | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  | 1.38335 |     0.5001 |                    3 |
# | DEFAULT_20a51_00006 | RUNNING    | 127.0.0.1:46640 |            4 |   16 |   16 | 0.00260165  | 1.50013 |     0.4471 |                    2 |
# | DEFAULT_20a51_00008 | RUNNING    | 127.0.0.1:38436 |            2 |    8 |    4 | 0.0398717   |         |            |                      |
# | DEFAULT_20a51_00009 | RUNNING    | 127.0.0.1:58256 |            4 |   64 |  256 | 0.0458157   |         |            |                      |
# | DEFAULT_20a51_00000 | TERMINATED | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  | 1.8427  |     0.2846 |                    2 |
# | DEFAULT_20a51_00001 | TERMINATED | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   | 2.31107 |     0.0972 |                    1 |
# | DEFAULT_20a51_00002 | TERMINATED | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 | 2.30503 |     0.097  |                    1 |
# | DEFAULT_20a51_00005 | TERMINATED | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  | 1.55219 |     0.4545 |                    2 |
# | DEFAULT_20a51_00007 | TERMINATED | 127.0.0.1:40848 |           16 |   64 |   16 | 0.0001704   | 2.30338 |     0.1433 |                    1 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
#  pid=38900) [4,  2000] loss: 1.424
# == Status ==
# Current time: 2022-02-18 20:44:48 (running for 00:07:29.71)
# Memory usage on this node: 22.6/31.8 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.552187786269188 | Iter 1.000: -1.8936227770268916
# Resources requested: 10.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (5 RUNNING, 5 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_20a51_00003 | RUNNING    | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 | 1.4757  |     0.4649 |                    3 |
# | DEFAULT_20a51_00004 | RUNNING    | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  | 1.38335 |     0.5001 |                    3 |
# | DEFAULT_20a51_00006 | RUNNING    | 127.0.0.1:46640 |            4 |   16 |   16 | 0.00260165  | 1.50013 |     0.4471 |                    2 |
# | DEFAULT_20a51_00008 | RUNNING    | 127.0.0.1:38436 |            2 |    8 |    4 | 0.0398717   |         |            |                      |
# | DEFAULT_20a51_00009 | RUNNING    | 127.0.0.1:58256 |            4 |   64 |  256 | 0.0458157   |         |            |                      |
# | DEFAULT_20a51_00000 | TERMINATED | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  | 1.8427  |     0.2846 |                    2 |
# | DEFAULT_20a51_00001 | TERMINATED | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   | 2.31107 |     0.0972 |                    1 |
# | DEFAULT_20a51_00002 | TERMINATED | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 | 2.30503 |     0.097  |                    1 |
# | DEFAULT_20a51_00005 | TERMINATED | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  | 1.55219 |     0.4545 |                    2 |
# | DEFAULT_20a51_00007 | TERMINATED | 127.0.0.1:40848 |           16 |   64 |   16 | 0.0001704   | 2.30338 |     0.1433 |                    1 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# 2022-02-18 20:44:52,162	WARNING tune.py:592 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
# == Status ==
# Current time: 2022-02-18 20:44:52 (running for 00:07:33.77)
# Memory usage on this node: 22.3/31.8 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.552187786269188 | Iter 1.000: -1.8936227770268916
# Resources requested: 10.0/12 CPUs, 0/1 GPUs, 0.0/7.24 GiB heap, 0.0/3.62 GiB objects
# Result logdir: C:\Users\HYPC300\ray_results\DEFAULT_2022-02-18_20-37-18
# Number of trials: 10/10 (5 RUNNING, 5 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_20a51_00003 | RUNNING    | 127.0.0.1:38900 |           16 |   16 |   16 | 0.000951491 | 1.4757  |     0.4649 |                    3 |
# | DEFAULT_20a51_00004 | RUNNING    | 127.0.0.1:44324 |            8 |   64 |    4 | 0.00145566  | 1.38335 |     0.5001 |                    3 |
# | DEFAULT_20a51_00006 | RUNNING    | 127.0.0.1:46640 |            4 |   16 |   16 | 0.00260165  | 1.50013 |     0.4471 |                    2 |
# | DEFAULT_20a51_00008 | RUNNING    | 127.0.0.1:38436 |            2 |    8 |    4 | 0.0398717   |         |            |                      |
# | DEFAULT_20a51_00009 | RUNNING    | 127.0.0.1:58256 |            4 |   64 |  256 | 0.0458157   |         |            |                      |
# | DEFAULT_20a51_00000 | TERMINATED | 127.0.0.1:44984 |            2 |    8 |    4 | 0.00250225  | 1.8427  |     0.2846 |                    2 |
# | DEFAULT_20a51_00001 | TERMINATED | 127.0.0.1:36076 |            4 |    4 |  256 | 0.0121433   | 2.31107 |     0.0972 |                    1 |
# | DEFAULT_20a51_00002 | TERMINATED | 127.0.0.1:64192 |            8 |   32 |    8 | 0.000106766 | 2.30503 |     0.097  |                    1 |
# | DEFAULT_20a51_00005 | TERMINATED | 127.0.0.1:45108 |            4 |   32 |  128 | 0.00333808  | 1.55219 |     0.4545 |                    2 |
# | DEFAULT_20a51_00007 | TERMINATED | 127.0.0.1:40848 |           16 |   64 |   16 | 0.0001704   | 2.30338 |     0.1433 |                    1 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#  pid=46640) Traceback (most recent call last):
#  pid=46640)   File "<string>", line 1, in <module>
#  pid=46640)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 116, in spawn_main
#  pid=46640)     exitcode = _main(fd, parent_sentinel)
#  pid=46640)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 124, in _main
#  pid=46640)     preparation_data = reduction.pickle.load(from_parent)
#  pid=46640) EOFError: Ran out of input
#  pid=38436) Traceback (most recent call last):
#  pid=38436)   File "<string>", line 1, in <module>
#  pid=38436)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 116, in spawn_main
#  pid=38436)     exitcode = _main(fd, parent_sentinel)
#  pid=38436)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 124, in _main
#  pid=38436)     preparation_data = reduction.pickle.load(from_parent)
#  pid=38436) EOFError: Ran out of input
#  pid=58256) Traceback (most recent call last):
#  pid=58256)   File "<string>", line 1, in <module>
#  pid=58256)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 116, in spawn_main
#  pid=58256)     exitcode = _main(fd, parent_sentinel)
#  pid=58256)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 124, in _main
#  pid=58256)     preparation_data = reduction.pickle.load(from_parent)
#  pid=58256) EOFError: Ran out of input
# 2022-02-18 20:44:52,435	ERROR tune.py:632 -- Trials did not complete: [DEFAULT_20a51_00003, DEFAULT_20a51_00004, DEFAULT_20a51_00006, DEFAULT_20a51_00008, DEFAULT_20a51_00009]
# 2022-02-18 20:44:52,436	INFO tune.py:636 -- Total run time: 454.16 seconds (453.76 seconds for the tuning loop).
# 2022-02-18 20:44:52,437	WARNING tune.py:640 -- Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
# Best trial config: {'l1': 64, 'l2': 4, 'lr': 0.0014556616076764708, 'batch_size': 8}
# Best trial final validation loss: 1.383349322795868
# Best trial final validation accuracy: 0.5001
# Files already downloaded and verified
#  pid=44324) Traceback (most recent call last):
#  pid=44324)   File "<string>", line 1, in <module>
#  pid=44324)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 116, in spawn_main
#  pid=44324)     exitcode = _main(fd, parent_sentinel)
#  pid=44324)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 126, in _main
#  pid=44324)     self = reduction.pickle.load(from_parent)
#  pid=44324) _pickle.UnpicklingError: pickle data was truncated
#  pid=38900) Traceback (most recent call last):
#  pid=38900)   File "<string>", line 1, in <module>
#  pid=38900)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 116, in spawn_main
#  pid=38900)     exitcode = _main(fd, parent_sentinel)
#  pid=38900)   File "C:\Users\HYPC300\anaconda3\envs\basic_NN_study\lib\multiprocessing\spawn.py", line 126, in _main
#  pid=38900)     self = reduction.pickle.load(from_parent)
#  pid=38900) _pickle.UnpicklingError: pickle data was truncated
# Files already downloaded and verified
# Best trial test set accuracy: 0.5014
